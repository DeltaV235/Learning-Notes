# %% [markdown]
# # LangSmith Test

# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain_deepseek import ChatDeepSeek
from rich import print as rprint

# %% [markdown]
# ## Demo 1

# %%
# 将env文件中的变量加载为环境变量
# override=True：表示.env优先
load_dotenv(override=True)

model = ChatDeepSeek(
    model="deepseek-v4-flash"
)
print(model.invoke("你好"))
# Out:
# content='你好！很高兴见到你。😊 有什么我可以帮你的吗？无论是解答问题、聊天，还是其他需求，我都乐意为你提供帮助！' additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户发了一句简单的问候“你好”。这是一个非常常见的开场白，没有提出具体问题或需求。用户可能只是想打个招呼，测试我是否在线，或者准备开始一段对话。我需要以友好、热情的方式回应，同时保持开放，邀请用户提出后续问题。可以用自我介绍和表示愿意提供帮助来开启对话，语气要亲切自然。'} response_metadata={'token_usage': {'completion_tokens': 106, 'prompt_tokens': 5, 'total_tokens': 111, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 74, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 5}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '4926590c-0747-4b83-8076-ef39b3fcd468', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f6bba-4c44-7b31-bb13-f4e465f47af9-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 5, 'output_tokens': 106, 'total_tokens': 111, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 74}}

# %% [markdown]
# ## Demo 2

# %%
model = init_chat_model(model="openrouter:x-ai/grok-4.5")
rprint(model.invoke("Introduce yourself, response in Chinese"))
# Out:
# AIMessage(
#     content='你好！我是Grok，由xAI打造的AI助手。\n\n我的目标是尽量真实、有用、带点幽默地回答问题、解释事物，并帮助
# 你探索宇宙与世界。有什么想聊的或需要帮忙的，随时告诉我吧！😊',
#     additional_kwargs={
#         'reasoning_content': 'The user asked: "Introduce yourself, response in Chinese"\n',
#         'reasoning_details': [
#             {
#                 'type': 'reasoning.summary',
#                 'summary': 'The user asked: "Introduce yourself, response in Chinese"\n',
#                 'format': 'xai-responses-v1',
#                 'index': 0.0
#             },
#             {
#                 'type': 'reasoning.encrypted',
#                 'data':
# '8x15VzWsnE6kSsi01LVvvhz3llK0z1GJVe5XDuOB7ycwuZJ2SVWxG1u8wq1sReeg5lcRz8awWSAv1SnAutsBeWiVRjpfrVljvBau1Q48rG4HjCgooM
# cP5OLSVwfYgYWPuVg0fPeLAco84ooEGEtDkf6pL63tn+kFrGkRn6QQIpjS6QL+e2ZGTswGC634uyRRYvQH3Hoavx9ySQ+Uuo8PZiW28xs+Q27AkIQrz
# 4hydj8y2RDtulwSw0EvuacSr1rNSI4cnebTLg4b407QRQ7YjpKWQth4mh41OszZeM2D2NqyCJhdHf/r+sTOQPyvTkEbAH2IamgISpWySkItoMKugm8Q
# DGhXYRBPNE0ezEK7zoZKHgOQBdF5Dx0kiwyH1Dn3bhWMB2lEvWn0fYZ97Q3Wx9uK33iWc6F+uku649Ioa7uy2/LcpylvWsjq/j2In/Vgen4r6VJfCSw
# yIV/0fSs8jt8pyVlTeEX6qQKDtd25Mh9yJa/ZiTkKsqCBrmkUzuwaL233KzHXMUfVWRT6G0bSkv3oDUCivnUH7zgmDjumPccb528CmMLbf2TA5Ak9IY
# 1v6NlinAJgisTL7YXvz5gnl0+KpacAYcSFAGccxhnU1CH5WKHoDQQ9AAEFy201bZNDSrSHAQa3UjaWf6griW/zdN5J51O4FClKyDscgfsW06dQcaUN5
# LHp6YOhvodL7tlYSo9SAU7oZXkJn1BY7tzKf8d36g',
#                 'id': 'rs_a621d712-6e80-943c-8884-71cce349fd25',
#                 'format': 'xai-responses-v1',
#                 'index': 1.0
#             }
#         ]
#     },
#     response_metadata={
#         'model_name': 'x-ai/grok-4.5',
#         'id': 'gen-1784219366-Knt20e9Ps6kNSPLMJVbe',
#         'created': 1784219366,
#         'object': 'chat.completion',
#         'finish_reason': 'stop',
#         'logprobs': None,
#         'model_provider': 'openrouter'
#     },
#     id='lc_run--019f6bc2-f22e-7dc3-872b-e1a4a7b130dd-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 212,
#         'output_tokens': 181,
#         'total_tokens': 393,
#         'input_token_details': {'cache_read': 128, 'cache_creation': 0},
#         'output_token_details': {'reasoning': 121}
#     }
# )

# %% [markdown]
# ## Demo 3

# %%
import os

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_API_BASE")

# 1. 初始化模型
model = init_chat_model(
    model_provider="deepseek",
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    temperature=0.2,
    max_tokens=500,
    # 指定可调整参数
    configurable_fields=("model", "model_provider", "temperature", "max_tokens"),
)
# 2. 准备 config 字典
config = {
    "run_name": "joke_generation",  # 在LangSmith中这次运行会显示为
    "joke_generation"
    "tags": ["my_tag1", "my_tag2"],  # 打上标签便于分类查找
    "metadata": {
        "user_id": "shkstart",  # 记录用户ID
        "session_id": "sess_123"  # 记录会话ID
    },
    "configurable": {
        "model": "deepseek-v4-pro",  # 配置模型参数
        "model_provider": "openai",  # 配置模型提供商参数
        "temperature": 0.7,  # 配置温度参数
        "max_tokens": 1000  # 配置最大令牌数
    }
}
# 3. 调用模型并传入config
response = model.invoke(
    "1 + 2 = ？",
    config=config
)

rprint(response)
# Out:
# AIMessage(
#     content='1 + 2 = 3',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 33,
#             'prompt_tokens': 11,
#             'total_tokens': 44,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 25,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0},
#             'prompt_cache_hit_tokens': 0,
#             'prompt_cache_miss_tokens': 11
#         },
#         'model_provider': 'openai',
#         'model_name': 'deepseek-v4-pro',
#         'system_fingerprint': 'fp_9954b31ca7_prod0820_fp8_kvcache_20260402',
#         'id': '04133290-32a4-4582-9597-5f60d7be85ed',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--019f6bcf-b401-7500-aaa0-e70952263ab1-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 11,
#         'output_tokens': 33,
#         'total_tokens': 44,
#         'input_token_details': {'cache_read': 0},
#         'output_token_details': {'reasoning': 25}
#     }
# )
