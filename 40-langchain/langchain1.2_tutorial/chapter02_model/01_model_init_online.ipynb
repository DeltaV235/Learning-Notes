# %%
## DeepSeek

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

load_dotenv(override=True)

DEEPSEEK_API_BASE = os.getenv("DEEPSEEK_API_BASE")
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")

chat = ChatDeepSeek(base_url=DEEPSEEK_API_BASE,
                    api_key=DEEPSEEK_API_KEY,
                    model="deepseek-v4-flash")
chat = ChatDeepSeek(model="deepseek-v4-flash")
response = chat.invoke(input="hello, 你是什么模型")
print(response)
# Out:
# content='你好！我是 **DeepSeek**，由深度求索公司创造的人工智能模型。我是纯文本模型，支持处理海量信息（上下文可达1M），能够回答各种问题、辅助写作、分析文档等。虽然我不支持多模态识别（比如直接“看”图片），但可以读取上传的图像、PDF、Word、Excel等文件中的文字信息来帮你处理任务。\n\n我目前的版本是DeepSeek最新版模型，知识截止日期为2025年5月。完全免费使用，并且支持联网搜索（需要手动开启）。有什么我可以帮你的吗？😊' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户问了一个简单的自我介绍问题，询问我是什么模型。这是一个非常基础且常见的问题。我需要直接、清晰地告知用户我的身份和核心特点。想到了可以介绍我是DeepSeek，由深度求索公司创造，并简要说明我的关键能力，比如文本处理、文件上传、联网搜索等，同时提一下知识截止日期和免费性质，让用户快速了解我的基本功能和可用性。回复应该友好、信息明确，并以开放性问题结束，以便继续对话。'} response_metadata={'token_usage': {'completion_tokens': 227, 'prompt_tokens': 10, 'total_tokens': 237, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 102, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 10}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_2026040
# ...

# %%
from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

load_dotenv(override=True)

chat = ChatDeepSeek(model="deepseek-v4-flash")
response = chat.invoke(input="hello, 你是什么模型")
print(response)
# Out:
# content='你好！我是 **DeepSeek**，由深度求索公司创造的 AI 助手。我是最新版本的 DeepSeek 模型，知识截止日期为 2025 年 5 月。\n\n**我的一些特点：**\n- 🆓 **完全免费**，无收费计划\n- 📚 **超大上下文**：1M token，可以一次性处理像《三体》三部曲那样的长篇内容\n- 🌐 **支持联网搜索**（需要手动开启）\n- 📎 **文件上传**：支持图像、txt、pdf、ppt、word、excel 等多种格式\n- 🎤 **语音输入**（App 端支持）\n\n我会尽力为你提供热情、细腻的帮助，用中文回答你的问题。有什么我可以帮你的吗？😊' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户问“你是什么模型”，这是一个简单的自我介绍问题。用户可能想确认我的身份和能力，以便后续更有效地使用我。我需要直接、清晰地说明我是DeepSeek，并简要介绍我的核心特点，比如开发者、知识截止时间、免费、文件处理、联网搜索等关键信息，让用户快速了解我能做什么。最后用友好的语气结束，保持开放态度。'} response_metadata={'token_usage': {'completion_tokens': 244, 'prompt_tokens': 10, 'total_tokens': 254, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 81, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 10}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b33
# ...

# %% [markdown]
# ## Zhipu

# %%
from langchain_community.chat_models import ChatZhipuAI

load_dotenv(override=True)

chat = ChatZhipuAI(model="glm-5.2")
response = chat.invoke(input="hello, 你是什么模型")
print(response)
# Out:
# content='我是GLM（General Language Model），由Z.ai开发训练的大语言模型。我基于对大量文本数据的学习，能够理解和生成人类语言，回答问题并提供信息。\n\n我会不断学习和更新以提升自己的能力，但也有知识范围和能力的限制。很高兴能与您交流，有什么我可以帮助您的问题吗？' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 246, 'completion_tokens_details': {'reasoning_tokens': 178}, 'prompt_tokens': 17, 'prompt_tokens_details': {'cached_tokens': 0}, 'total_tokens': 263}, 'model_name': 'glm-5.2', 'finish_reason': 'stop'} id='lc_run--019f0457-01f2-7d62-bbab-4b80a875a89c-0' tool_calls=[] invalid_tool_calls=[]
