# %%
## Temperature

# %%
from dotenv import load_dotenv
from langchain.chat_models.base import init_chat_model
from openai.types.shared_params import reasoning

load_dotenv(override=True)

model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    temperature=1.9,
)
response = model.invoke("帮我写一首关于春天的七言绝句").content
print(response)
# Out:
# 《七绝·早春》
# 水暖风轻燕早归，垂杨拂岸绿波微。
# 一宵细雨添新色，万树梨花带露飞。
#
# 注：本诗以早春为背景，通过“燕归”、“垂杨”、“细雨”、“梨花”等意象，描绘春意初萌的清新画卷。首句“水暖风轻”暗合气候转暖，“万树梨花”以夸张手法渲染春色璀璨，尾句“带露飞”赋予静态花朵以动态生机，全诗格律工整，意境空灵，深得七绝含蓄蕴藉之妙。

# %%
from dotenv import load_dotenv
from langchain.chat_models.base import init_chat_model

load_dotenv(override=True)

model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    temperature=1.9,
)
response = model.invoke("张三，男，30岁，拥有8年编程开发经验，目前在某互联网大厂担任技术专家。帮我从上文中提取数据，返回JSON格式").content
print(response)
# Out:
# {
#   "name": "张三",
#   "gender": "男",
#   "age": 30,
#   "experience_years": 8,
#   "position": "技术专家",
#   "company": "某互联网大厂"
# }

# %%
from dotenv import load_dotenv
from langchain.chat_models.base import init_chat_model

load_dotenv(override=True)

model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    temperature=0,
)
response = model.invoke("张三，男，30岁，拥有8年编程开发经验，目前在某互联网大厂担任技术专家。帮我从上文中提取数据，返回JSON格式").content
print(response)
# Out:
# ```json
# {
#   "name": "张三",
#   "gender": "男",
#   "age": 30,
#   "experience_years": 8,
#   "current_position": "技术专家",
#   "company": "某互联网大厂"
# }
# ```

# %% [markdown]
# ## max_token
# 思考使用的 Token 也包含在 max_token 这个参数中

# %%
from dotenv import load_dotenv
from langchain.chat_models.base import init_chat_model

load_dotenv(override=True)

model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    temperature=0,
    max_tokens=190,
)
response = model.invoke("张三，男，30岁，拥有8年编程开发经验，目前在某互联网大厂担任技术专家。帮我从上文中提取数据，返回JSON格式")
print(response)
# Out:
# content='{\n  "name": "张三",\n  "gender": "男",\n  "age": 30,\n  "workExperience": "8年",\n  "position": "技术专家",\n  "company": "某互联网大厂"\n}' additional_kwargs={'refusal': None, 'reasoning_content': '我们要求从上文中提取数据。原文：张三，男，30岁，拥有8年编程开发经验，目前在某互联网大厂担任技术专家。\n\n提取的数据：姓名、性别、年龄、工作经验、职位、公司（注意公司是“某互联网大厂”，不是具体名称）。另外也可以提取经验年限。返回JSON格式。\n\n需要明确字段名：name, gender, age, workExperience, position, company。注意年龄是30岁，工作经验是8年，职位是技术专家，公司是某互联网大厂。\n\n输出JSON。'} response_metadata={'token_usage': {'completion_tokens': 165, 'prompt_tokens': 36, 'total_tokens': 201, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 114, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 36}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '1c3c53ae-3b25-42af-8b92-daea1b440c85',
# ...
